# %%
print('Hello, World')
# Out:
# Running cells with 'Python 3.8.2 64-bit' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
import svgwrite

dwg = svgwrite.Drawing('svgwrite-example.svg', profile='tiny')

# draw a red box
dwg.add(dwg.rect((10, 10), (300, 200),
    stroke=svgwrite.rgb(10, 10, 16, '%'),
    fill='red')
)

# Draw a small
dwg.save()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/christopherhunter/svgwriteExample.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/christopherhunter/svgwriteExample.ipynb#ch0000001?line=0'>1</a> import svgwrite
#       <a href='vscode-notebook-cell:/Users/christopherhunter/svgwriteExample.ipynb#ch0000001?line=2'>3</a> dwg = svgwrite.Drawing('svgwrite-example.svg', profile='tiny')
#       <a href='vscode-notebook-cell:/Users/christopherhunter/svgwriteExample.ipynb#ch0000001?line=4'>5</a> # draw a red box
#
# ModuleNotFoundError: No module named 'svgwrite'
